# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# there is 10 dirffrent labels due to its name "CIFAR-10" :)
#
# its look like the image data is 0-252 in the fifth image, so its looks like the input values will be between 0-255
#
# the data is saved randomly, it can be confirmd by lokking at the first 20 lables

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    # z=(xi-min(x))/(max(x)-min(x))
    # z=(xi-0)/(255-0)
    # z=(xi)/(255)
    # z=xi/255
    
    return x / 255

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    result = np.zeros((len(x), 10))
    # 10 bacause there is 10 labels, i have tried with max(10) but it was giving me inconsistents results in the unit test
    
    result[np.arange(len(x)), x] = 1 # i think it is overkill to import another libery for just one simple function

    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# If you're finding it hard to dedicate enough time for this course a week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) to build each layer, except "Convolutional & Max Pooling" layer.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# If you would like to get the most of this course, try to solve all the problems without TF Layers.  Let's begin!
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, image_shape[0], image_shape[1], image_shape[2]], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# Note: You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.  You're free to use any TensorFlow package for all the other layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Functionshape = x_tensor.get_shape().as_list()
    shape = x_tensor.get_shape().as_list()
    filter_weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], shape[3], conv_num_outputs], stddev=0.05, mean=0.01))
    
    filter_bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    output = tf.nn.conv2d(x_tensor, filter_weight, [1,conv_strides[0],conv_strides[1],1], 'SAME') + filter_bias
    output = tf.nn.relu(output)
    output = tf.nn.max_pool(output, [1, pool_ksize[0], pool_ksize[1], 1], [1, pool_strides[0], pool_strides[1], 1], 'SAME')
    return output

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape()[1:].num_elements()
    
    return tf.reshape(x_tensor, [-1, shape])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_input = int(x_tensor.get_shape()[1])
    
    weight = tf.Variable(tf.truncated_normal([num_input, num_outputs ], stddev=0.04, mean=0.01))
    biases = tf.Variable(tf.zeros(num_outputs))
    
    output = tf.matmul(x_tensor, weight) + biases
    
    output = tf.nn.relu(output) # i got the attention on this problem after i sent the assignment, but i did not have time to run the script again 
        
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.
#
# Note: Activation, softmax, or cross entropy shouldn't be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_input = int(x_tensor.get_shape()[1])
    
    weight = tf.Variable(tf.truncated_normal([num_input, num_outputs ], stddev=0.04, mean=0.01))
    biases = tf.Variable(tf.zeros(num_outputs))
    
    output = tf.matmul(x_tensor, weight) + biases

    # why is a activation function like sigmoid not applyed here?
    # i thougt we allways should apply a activation function when we are predictiong a class  
    # i classmate cleard out my question, its because we are using cross_entropy
    
    return output




"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    net = x # i dont know how this stupid fail is from, i am 100% sure i fixed it last week, i must have forgoten to save
    
    for i in range(2):
        net = conv2d_maxpool(net, 20, (5,5), (1,1), (3,3), (2,2) )
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    net = flatten(net)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    for i in range(3):
        net = fully_conn(net, 64)
        net = tf.nn.dropout(net, keep_prob)

    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    net = output(net, 10)
        
    # TODO: return output
    return net


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={keep_prob: keep_probability, x: feature_batch, y: label_batch})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    acc = session.run(accuracy, feed_dict={ keep_prob: 1., x:valid_features, y:valid_labels }) # this make sence, validation should see on more then the batch, and loos is just for the batch
    loss = session.run(cost, feed_dict={ keep_prob: 1., x:feature_batch, y:label_batch })

    print ('Loss: {:0.7f}, accuracy {:0.3f}%: '.format(loss, acc*100))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 512  # i have no memory problems, i was just thought it would faster traning while i have the computer problems
keep_probability = .5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.3019676, accuracy 10.760%:
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2.3022695, accuracy 9.980%:
# Epoch  3, CIFAR-10 Batch 1:  Loss: 2.3022840, accuracy 9.980%:
# Epoch  4, CIFAR-10 Batch 1:  Loss: 2.3022785, accuracy 9.980%:
# Epoch  5, CIFAR-10 Batch 1:  Loss: 2.3022485, accuracy 9.980%:
# Epoch  6, CIFAR-10 Batch 1:  Loss: 2.3022263, accuracy 11.280%:
# Epoch  7, CIFAR-10 Batch 1:  Loss: 2.3022332, accuracy 10.500%:
# Epoch  8, CIFAR-10 Batch 1:  Loss: 2.3022466, accuracy 10.500%:
# Epoch  9, CIFAR-10 Batch 1:  Loss: 2.3022294, accuracy 10.500%:
# Epoch 10, CIFAR-10 Batch 1:  Loss: 2.3021996, accuracy 10.500%:
# Epoch 11, CIFAR-10 Batch 1:  Loss: 2.3021679, accuracy 10.500%:
# Epoch 12, CIFAR-10 Batch 1:  Loss: 2.3021500, accuracy 10.500%:
# Epoch 13, CIFAR-10 Batch 1:  Loss: 2.3021157, accuracy 10.500%:
# Epoch 14, CIFAR-10 Batch 1:  Loss: 2.3020391, accuracy 10.500%:
# Epoch 15, CIFAR-10 Batch 1:  Loss: 2.3019872, accuracy 10.500%:
# Epoch 16, CIFAR-10 Batch 1:  Loss: 2.3018486, accuracy 10.500%:
# Epoch 17, CIFAR-10 Batch 1:  Loss: 2.3015976, accuracy 10.500%:
# Epoch 18, CIFAR-10 Batch 1:  Loss: 2.3011880, accuracy 10.500%:
# Epoch 19, CIFAR-10 Batch 1:  Loss: 2.3005064, accuracy 10.500%:
# Epoch 20, CIFAR-10 Batch 1:  Loss: 2.2991188, accuracy 10.500%:
# Epoch 21, CIFAR-10 Batch 1:  Loss: 2.2957981, accuracy 10.660%:
# Epoch 22, CIFAR-10 Batch 1:  Loss: 2.2886391, accuracy 11.260%:
# Epoch 23, CIFAR-10 Batch 1:  Loss: 2.2701695, accuracy 14.000%:
# Epoch 24, CIFAR-10 Batch 1:  Loss: 2.2253871, accuracy 17.920%:
# Epoch 25, CIFAR-10 Batch 1:  Loss: 2.1870203, accuracy 16.580%:
# Epoch 26, CIFAR-10 Batch 1:  Loss: 2.1793680, accuracy 16.480%:
# Epoch 27, CIFAR-10 Batch 1:  Loss: 2.1830375, accuracy 18.660%:
# Epoch 28, CIFAR-10 Batch 1:  Loss: 2.1570945, accuracy 19.960%:
# Epoch 29, CIFAR-10 Batch 1:  Loss: 2.1476045, accuracy 19.540%:
# Epoch 30, CIFAR-10 Batch 1:  Loss: 2.1373723, accuracy 19.640%:
# Epoch 31, CIFAR-10 Batch 1:  Loss: 2.1259553, accuracy 20.080%:
# Epoch 32, CIFAR-10 Batch 1:  Loss: 2.1157935, accuracy 19.560%:
# Epoch 33, CIFAR-10 Batch 1:  Loss: 2.1046376, accuracy 20.360%:
# Epoch 34, CIFAR-10 Batch 1:  Loss: 2.1057975, accuracy 20.840%:
# Epoch 35, CIFAR-10 Batch 1:  Loss: 2.0540428, accuracy 19.840%:
# Epoch 36, CIFAR-10 Batch 1:  Loss: 2.0665069, accuracy 20.220%:
# Epoch 37, CIFAR-10 Batch 1:  Loss: 2.0329494, accuracy 20.320%:
# Epoch 38, CIFAR-10 Batch 1:  Loss: 2.0291250, accuracy 20.100%:
# Epoch 39, CIFAR-10 Batch 1:  Loss: 2.0071745, accuracy 20.720%:
# Epoch 40, CIFAR-10 Batch 1:  Loss: 2.0054390, accuracy 20.040%:
# Epoch 41, CIFAR-10 Batch 1:  Loss: 2.0529656, accuracy 19.260%:
# Epoch 42, CIFAR-10 Batch 1:  Loss: 1.9879018, accuracy 20.480%:
# Epoch 43, CIFAR-10 Batch 1:  Loss: 1.9822981, accuracy 21.080%:
# Epoch 44, CIFAR-10 Batch 1:  Loss: 1.9822153, accuracy 20.480%:
# Epoch 45, CIFAR-10 Batch 1:  Loss: 1.9761982, accuracy 21.180%:
# Epoch 46, CIFAR-10 Batch 1:  Loss: 1.9692564, accuracy 20.640%:
# Epoch 47, CIFAR-10 Batch 1:  Loss: 1.9629943, accuracy 21.120%:
# Epoch 48, CIFAR-10 Batch 1:  Loss: 1.9681671, accuracy 20.300%:
# Epoch 49, CIFAR-10 Batch 1:  Loss: 1.9469466, accuracy 20.600%:
# Epoch 50, CIFAR-10 Batch 1:  Loss: 1.9646657, accuracy 19.860%:
# Epoch 51, CIFAR-10 Batch 1:  Loss: 1.9326336, accuracy 21.220%:
# Epoch 52, CIFAR-10 Batch 1:  Loss: 1.9281373, accuracy 21.120%:
# Epoch 53, CIFAR-10 Batch 1:  Loss: 1.9222478, accuracy 21.240%:
# Epoch 54, CIFAR-10 Batch 1:  Loss: 1.9135815, accuracy 21.080%:
# Epoch 55, CIFAR-10 Batch 1:  Loss: 1.9059337, accuracy 21.740%:
# Epoch 56, CIFAR-10 Batch 1:  Loss: 1.9218121, accuracy 21.060%:
# Epoch 57, CIFAR-10 Batch 1:  Loss: 1.9020776, accuracy 21.200%:
# Epoch 58, CIFAR-10 Batch 1:  Loss: 1.8882127, accuracy 22.660%:
# Epoch 59, CIFAR-10 Batch 1:  Loss: 1.8884571, accuracy 23.780%:
# Epoch 60, CIFAR-10 Batch 1:  Loss: 1.8728790, accuracy 24.800%:
# Epoch 61, CIFAR-10 Batch 1:  Loss: 1.8604954, accuracy 22.620%:
# Epoch 62, CIFAR-10 Batch 1:  Loss: 1.8563507, accuracy 24.640%:
# Epoch 63, CIFAR-10 Batch 1:  Loss: 1.8640331, accuracy 24.400%:
# Epoch 64, CIFAR-10 Batch 1:  Loss: 1.8345089, accuracy 27.520%:
# Epoch 65, CIFAR-10 Batch 1:  Loss: 1.8136535, accuracy 27.760%:
# Epoch 66, CIFAR-10 Batch 1:  Loss: 1.8130205, accuracy 29.420%:
# Epoch 67, CIFAR-10 Batch 1:  Loss: 1.7560750, accuracy 30.340%:
# Epoch 68, CIFAR-10 Batch 1:  Loss: 1.7346457, accuracy 29.740%:
# Epoch 69, CIFAR-10 Batch 1:  Loss: 1.7339193, accuracy 30.600%:
# Epoch 70, CIFAR-10 Batch 1:  Loss: 1.6986213, accuracy 31.380%:
# Epoch 71, CIFAR-10 Batch 1:  Loss: 1.6703576, accuracy 31.860%:
# Epoch 72, CIFAR-10 Batch 1:  Loss: 1.6883075, accuracy 30.900%:
# Epoch 73, CIFAR-10 Batch 1:  Loss: 1.6948775, accuracy 30.280%:
# Epoch 74, CIFAR-10 Batch 1:  Loss: 1.6602329, accuracy 33.120%:
# Epoch 75, CIFAR-10 Batch 1:  Loss: 1.6190441, accuracy 33.300%:
# Epoch 76, CIFAR-10 Batch 1:  Loss: 1.5941743, accuracy 34.600%:
# Epoch 77, CIFAR-10 Batch 1:  Loss: 1.5873555, accuracy 35.000%:
# Epoch 78, CIFAR-10 Batch 1:  Loss: 1.5703541, accuracy 35.440%:
# Epoch 79, CIFAR-10 Batch 1:  Loss: 1.5487324, accuracy 35.160%:
# Epoch 80, CIFAR-10 Batch 1:  Loss: 1.5176895, accuracy 35.240%:
# Epoch 81, CIFAR-10 Batch 1:  Loss: 1.5143201, accuracy 35.540%:
# Epoch 82, CIFAR-10 Batch 1:  Loss: 1.5121418, accuracy 36.740%:
# Epoch 83, CIFAR-10 Batch 1:  Loss: 1.4533751, accuracy 37.620%:
# Epoch 84, CIFAR-10 Batch 1:  Loss: 1.4364523, accuracy 37.860%:
# Epoch 85, CIFAR-10 Batch 1:  Loss: 1.4117589, accuracy 37.980%:
# Epoch 86, CIFAR-10 Batch 1:  Loss: 1.4152409, accuracy 38.340%:
# Epoch 87, CIFAR-10 Batch 1:  Loss: 1.3795459, accuracy 39.780%:
# Epoch 88, CIFAR-10 Batch 1:  Loss: 1.3809359, accuracy 39.520%:
# Epoch 89, CIFAR-10 Batch 1:  Loss: 1.3585652, accuracy 40.040%:
# Epoch 90, CIFAR-10 Batch 1:  Loss: 1.3114942, accuracy 40.520%:
# Epoch 91, CIFAR-10 Batch 1:  Loss: 1.2950827, accuracy 40.040%:
# Epoch 92, CIFAR-10 Batch 1:  Loss: 1.3003012, accuracy 39.760%:
# Epoch 93, CIFAR-10 Batch 1:  Loss: 1.2986088, accuracy 39.720%:
# Epoch 94, CIFAR-10 Batch 1:  Loss: 1.2663232, accuracy 40.800%:
# Epoch 95, CIFAR-10 Batch 1:  Loss: 1.2815204, accuracy 40.160%:
# Epoch 96, CIFAR-10 Batch 1:  Loss: 1.2569219, accuracy 41.260%:
# Epoch 97, CIFAR-10 Batch 1:  Loss: 1.2106953, accuracy 41.700%:
# Epoch 98, CIFAR-10 Batch 1:  Loss: 1.2104987, accuracy 42.060%:
# Epoch 99, CIFAR-10 Batch 1:  Loss: 1.2323020, accuracy 40.340%:
# Epoch 100, CIFAR-10 Batch 1:  Loss: 1.1792059, accuracy 43.120%:

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss: 2.3019137, accuracy 9.660%:
# Epoch  1, CIFAR-10 Batch 2:  Loss: 2.3019569, accuracy 9.460%:
# Epoch  1, CIFAR-10 Batch 3:  Loss: 2.3020425, accuracy 9.520%:
# Epoch  1, CIFAR-10 Batch 4:  Loss: 2.3024123, accuracy 9.420%:
# Epoch  1, CIFAR-10 Batch 5:  Loss: 2.3025796, accuracy 9.420%:
# Epoch  2, CIFAR-10 Batch 1:  Loss: 2.3024201, accuracy 9.420%:
# Epoch  2, CIFAR-10 Batch 2:  Loss: 2.3020346, accuracy 9.540%:
# Epoch  2, CIFAR-10 Batch 3:  Loss: 2.3020899, accuracy 9.420%:
# Epoch  2, CIFAR-10 Batch 4:  Loss: 2.3024299, accuracy 9.420%:
# Epoch  2, CIFAR-10 Batch 5:  Loss: 2.3024466, accuracy 9.420%:
# Epoch  3, CIFAR-10 Batch 1:  Loss: 2.3024287, accuracy 9.420%:
# Epoch  3, CIFAR-10 Batch 2:  Loss: 2.3020873, accuracy 10.560%:
# Epoch  3, CIFAR-10 Batch 3:  Loss: 2.3021896, accuracy 9.420%:
# Epoch  3, CIFAR-10 Batch 4:  Loss: 2.3023338, accuracy 9.420%:
# Epoch  3, CIFAR-10 Batch 5:  Loss: 2.3023441, accuracy 9.420%:
# Epoch  4, CIFAR-10 Batch 1:  Loss: 2.3023715, accuracy 9.420%:
# Epoch  4, CIFAR-10 Batch 2:  Loss: 2.3018968, accuracy 10.300%:
# Epoch  4, CIFAR-10 Batch 3:  Loss: 2.3020737, accuracy 9.420%:
# Epoch  4, CIFAR-10 Batch 4:  Loss: 2.3021603, accuracy 9.420%:
# Epoch  4, CIFAR-10 Batch 5:  Loss: 2.3021116, accuracy 9.420%:
# Epoch  5, CIFAR-10 Batch 1:  Loss: 2.3020675, accuracy 9.420%:
# Epoch  5, CIFAR-10 Batch 2:  Loss: 2.3013484, accuracy 10.740%:
# Epoch  5, CIFAR-10 Batch 3:  Loss: 2.3014786, accuracy 10.860%:
# Epoch  5, CIFAR-10 Batch 4:  Loss: 2.3013215, accuracy 9.420%:
# Epoch  5, CIFAR-10 Batch 5:  Loss: 2.3009024, accuracy 11.380%:
# Epoch  6, CIFAR-10 Batch 1:  Loss: 2.2998939, accuracy 14.460%:
# Epoch  6, CIFAR-10 Batch 2:  Loss: 2.2977948, accuracy 14.280%:
# Epoch  6, CIFAR-10 Batch 3:  Loss: 2.2974718, accuracy 12.180%:
# Epoch  6, CIFAR-10 Batch 4:  Loss: 2.2932954, accuracy 14.860%:
# Epoch  6, CIFAR-10 Batch 5:  Loss: 2.2848635, accuracy 12.860%:
# Epoch  7, CIFAR-10 Batch 1:  Loss: 2.2681825, accuracy 15.560%:
# Epoch  7, CIFAR-10 Batch 2:  Loss: 2.2297029, accuracy 16.060%:
# Epoch  7, CIFAR-10 Batch 3:  Loss: 2.2082365, accuracy 17.640%:
# Epoch  7, CIFAR-10 Batch 4:  Loss: 2.1753101, accuracy 19.160%:
# Epoch  7, CIFAR-10 Batch 5:  Loss: 2.1636252, accuracy 18.420%:
# Epoch  8, CIFAR-10 Batch 1:  Loss: 2.1739113, accuracy 18.880%:
# Epoch  8, CIFAR-10 Batch 2:  Loss: 2.1570890, accuracy 20.520%:
# Epoch  8, CIFAR-10 Batch 3:  Loss: 2.1340950, accuracy 19.220%:
# Epoch  8, CIFAR-10 Batch 4:  Loss: 2.1063623, accuracy 20.240%:
# Epoch  8, CIFAR-10 Batch 5:  Loss: 2.1092145, accuracy 19.360%:
# Epoch  9, CIFAR-10 Batch 1:  Loss: 2.1186140, accuracy 20.320%:
# Epoch  9, CIFAR-10 Batch 2:  Loss: 2.0673645, accuracy 21.100%:
# Epoch  9, CIFAR-10 Batch 3:  Loss: 2.0116978, accuracy 20.900%:
# Epoch  9, CIFAR-10 Batch 4:  Loss: 1.9884717, accuracy 20.800%:
# Epoch  9, CIFAR-10 Batch 5:  Loss: 2.0101488, accuracy 20.500%:
# Epoch 10, CIFAR-10 Batch 1:  Loss: 2.0252602, accuracy 20.460%:
# Epoch 10, CIFAR-10 Batch 2:  Loss: 1.9807680, accuracy 20.040%:
# Epoch 10, CIFAR-10 Batch 3:  Loss: 1.8969857, accuracy 22.000%:
# Epoch 10, CIFAR-10 Batch 4:  Loss: 1.9070385, accuracy 19.960%:
# Epoch 10, CIFAR-10 Batch 5:  Loss: 1.9431981, accuracy 19.480%:
# Epoch 11, CIFAR-10 Batch 1:  Loss: 1.9649454, accuracy 20.500%:
# Epoch 11, CIFAR-10 Batch 2:  Loss: 1.9244335, accuracy 21.620%:
# Epoch 11, CIFAR-10 Batch 3:  Loss: 1.8431671, accuracy 19.320%:
# Epoch 11, CIFAR-10 Batch 4:  Loss: 1.8902653, accuracy 20.840%:
# Epoch 11, CIFAR-10 Batch 5:  Loss: 1.9057549, accuracy 19.660%:
# Epoch 12, CIFAR-10 Batch 1:  Loss: 1.9387181, accuracy 21.720%:
# Epoch 12, CIFAR-10 Batch 2:  Loss: 1.8969576, accuracy 21.600%:
# Epoch 12, CIFAR-10 Batch 3:  Loss: 1.8470942, accuracy 20.060%:
# Epoch 12, CIFAR-10 Batch 4:  Loss: 1.8337131, accuracy 21.700%:
# Epoch 12, CIFAR-10 Batch 5:  Loss: 1.8733799, accuracy 22.160%:
# Epoch 13, CIFAR-10 Batch 1:  Loss: 1.9162220, accuracy 24.960%:
# Epoch 13, CIFAR-10 Batch 2:  Loss: 1.8701016, accuracy 24.000%:
# Epoch 13, CIFAR-10 Batch 3:  Loss: 1.8351222, accuracy 23.580%:
# Epoch 13, CIFAR-10 Batch 4:  Loss: 1.8172271, accuracy 25.160%:
# Epoch 13, CIFAR-10 Batch 5:  Loss: 1.8422439, accuracy 27.080%:
# Epoch 14, CIFAR-10 Batch 1:  Loss: 1.8804445, accuracy 29.320%:
# Epoch 14, CIFAR-10 Batch 2:  Loss: 1.8203554, accuracy 28.920%:
# Epoch 14, CIFAR-10 Batch 3:  Loss: 1.7311721, accuracy 27.480%:
# Epoch 14, CIFAR-10 Batch 4:  Loss: 1.7126681, accuracy 29.480%:
# Epoch 14, CIFAR-10 Batch 5:  Loss: 1.7570580, accuracy 29.680%:
# Epoch 15, CIFAR-10 Batch 1:  Loss: 1.8030406, accuracy 30.680%:
# Epoch 15, CIFAR-10 Batch 2:  Loss: 1.7535937, accuracy 32.180%:
# Epoch 15, CIFAR-10 Batch 3:  Loss: 1.6886129, accuracy 29.800%:
# Epoch 15, CIFAR-10 Batch 4:  Loss: 1.6488221, accuracy 32.320%:
# Epoch 15, CIFAR-10 Batch 5:  Loss: 1.6999737, accuracy 31.420%:
# Epoch 16, CIFAR-10 Batch 1:  Loss: 1.7690995, accuracy 31.840%:
# Epoch 16, CIFAR-10 Batch 2:  Loss: 1.7101368, accuracy 32.360%:
# Epoch 16, CIFAR-10 Batch 3:  Loss: 1.6359326, accuracy 32.280%:
# Epoch 16, CIFAR-10 Batch 4:  Loss: 1.6050143, accuracy 33.680%:
# Epoch 16, CIFAR-10 Batch 5:  Loss: 1.6731424, accuracy 32.940%:
# Epoch 17, CIFAR-10 Batch 1:  Loss: 1.7110099, accuracy 33.860%:
# Epoch 17, CIFAR-10 Batch 2:  Loss: 1.6626568, accuracy 34.360%:
# Epoch 17, CIFAR-10 Batch 3:  Loss: 1.5635301, accuracy 33.840%:
# Epoch 17, CIFAR-10 Batch 4:  Loss: 1.5385736, accuracy 35.960%:
# Epoch 17, CIFAR-10 Batch 5:  Loss: 1.6149966, accuracy 36.700%:
# Epoch 18, CIFAR-10 Batch 1:  Loss: 1.6763263, accuracy 37.180%:
# Epoch 18, CIFAR-10 Batch 2:  Loss: 1.6345309, accuracy 37.260%:
# Epoch 18, CIFAR-10 Batch 3:  Loss: 1.5176115, accuracy 37.000%:
# Epoch 18, CIFAR-10 Batch 4:  Loss: 1.4789894, accuracy 38.280%:
# Epoch 18, CIFAR-10 Batch 5:  Loss: 1.5665326, accuracy 36.960%:
# Epoch 19, CIFAR-10 Batch 1:  Loss: 1.6423455, accuracy 38.240%:
# Epoch 19, CIFAR-10 Batch 2:  Loss: 1.5700209, accuracy 37.060%:
# Epoch 19, CIFAR-10 Batch 3:  Loss: 1.4730490, accuracy 38.620%:
# Epoch 19, CIFAR-10 Batch 4:  Loss: 1.4366349, accuracy 39.280%:
# Epoch 19, CIFAR-10 Batch 5:  Loss: 1.5175890, accuracy 38.900%:
# Epoch 20, CIFAR-10 Batch 1:  Loss: 1.5863850, accuracy 40.000%:
# Epoch 20, CIFAR-10 Batch 2:  Loss: 1.5160238, accuracy 39.460%:
# Epoch 20, CIFAR-10 Batch 3:  Loss: 1.4451940, accuracy 39.780%:
# Epoch 20, CIFAR-10 Batch 4:  Loss: 1.3849454, accuracy 40.220%:
# Epoch 20, CIFAR-10 Batch 5:  Loss: 1.4677801, accuracy 40.700%:
# Epoch 21, CIFAR-10 Batch 1:  Loss: 1.5650557, accuracy 40.660%:
# Epoch 21, CIFAR-10 Batch 2:  Loss: 1.5121186, accuracy 39.340%:
# Epoch 21, CIFAR-10 Batch 3:  Loss: 1.4005418, accuracy 39.240%:
# Epoch 21, CIFAR-10 Batch 4:  Loss: 1.3764446, accuracy 40.280%:
# Epoch 21, CIFAR-10 Batch 5:  Loss: 1.4033622, accuracy 41.840%:
# Epoch 22, CIFAR-10 Batch 1:  Loss: 1.5184176, accuracy 41.880%:
# Epoch 22, CIFAR-10 Batch 2:  Loss: 1.4527600, accuracy 41.980%:
# Epoch 22, CIFAR-10 Batch 3:  Loss: 1.3860431, accuracy 41.020%:
# Epoch 22, CIFAR-10 Batch 4:  Loss: 1.3251393, accuracy 42.840%:
# Epoch 22, CIFAR-10 Batch 5:  Loss: 1.3808262, accuracy 42.500%:
# Epoch 23, CIFAR-10 Batch 1:  Loss: 1.5247464, accuracy 42.520%:
# Epoch 23, CIFAR-10 Batch 2:  Loss: 1.4066572, accuracy 42.180%:
# Epoch 23, CIFAR-10 Batch 3:  Loss: 1.3431054, accuracy 43.920%:
# Epoch 23, CIFAR-10 Batch 4:  Loss: 1.2735491, accuracy 45.220%:
# Epoch 23, CIFAR-10 Batch 5:  Loss: 1.3325930, accuracy 44.500%:
# Epoch 24, CIFAR-10 Batch 1:  Loss: 1.4429579, accuracy 44.600%:
# Epoch 24, CIFAR-10 Batch 2:  Loss: 1.3896757, accuracy 43.300%:
# Epoch 24, CIFAR-10 Batch 3:  Loss: 1.3042547, accuracy 45.760%:
# Epoch 24, CIFAR-10 Batch 4:  Loss: 1.2497525, accuracy 44.800%:
# Epoch 24, CIFAR-10 Batch 5:  Loss: 1.2967303, accuracy 45.360%:
# Epoch 25, CIFAR-10 Batch 1:  Loss: 1.4061065, accuracy 45.800%:
# Epoch 25, CIFAR-10 Batch 2:  Loss: 1.3571461, accuracy 43.720%:
# Epoch 25, CIFAR-10 Batch 3:  Loss: 1
# Epoch 44, CIFAR-10 Batch 3:  Loss: 0.8346637, accuracy 61.380%:
# Epoch 44, CIFAR-10 Batch 4:  Loss: 0.7792402, accuracy 62.100%:
# Epoch 44, CIFAR-10 Batch 5:  Loss: 0.8104041, accuracy 62.720%:
# Epoch 45, CIFAR-10 Batch 1:  Loss: 0.8756080, accuracy 62.620%:
# Epoch 45, CIFAR-10 Batch 2:  Loss: 0.9042528, accuracy 61.480%:
# Epoch 45, CIFAR-10 Batch 3:  Loss: 0.8064448, accuracy 62.240%:
# Epoch 45, CIFAR-10 Batch 4:  Loss: 0.7898177, accuracy 62.440%:
# Epoch 45, CIFAR-10 Batch 5:  Loss: 0.8123514, accuracy 63.400%:
# Epoch 46, CIFAR-10 Batch 1:  Loss: 0.8861590, accuracy 62.320%:
# Epoch 46, CIFAR-10 Batch 2:  Loss: 0.8782604, accuracy 62.980%:
# Epoch 46, CIFAR-10 Batch 3:  Loss: 0.8333929, accuracy 61.860%:
# Epoch 46, CIFAR-10 Batch 4:  Loss: 0.7712549, accuracy 62.360%:
# Epoch 46, CIFAR-10 Batch 5:  Loss: 0.8021460, accuracy 63.080%:
# Epoch 47, CIFAR-10 Batch 1:  Loss: 0.8388641, accuracy 63.340%:
# Epoch 47, CIFAR-10 Batch 2:  Loss: 0.8859916, accuracy 63.640%:
# Epoch 47, CIFAR-10 Batch 3:  Loss: 0.8059045, accuracy 62.780%:
# Epoch 47, CIFAR-10 Batch 4:  Loss: 0.7379991, accuracy 63.020%:
# Epoch 47, CIFAR-10 Batch 5:  Loss: 0.7820580, accuracy 64.140%:
# Epoch 48, CIFAR-10 Batch 1:  Loss: 0.8367116, accuracy 62.900%:
# Epoch 48, CIFAR-10 Batch 2:  Loss: 0.8321508, accuracy 63.900%:
# Epoch 48, CIFAR-10 Batch 3:  Loss: 0.7669840, accuracy 63.360%:
# Epoch 48, CIFAR-10 Batch 4:  Loss: 0.7708947, accuracy 62.060%:
# Epoch 48, CIFAR-10 Batch 5:  Loss: 0.8235216, accuracy 62.840%:
# Epoch 49, CIFAR-10 Batch 1:  Loss: 0.7950431, accuracy 64.220%:
# Epoch 49, CIFAR-10 Batch 2:  Loss: 0.8150153, accuracy 64.040%:
# Epoch 49, CIFAR-10 Batch 3:  Loss: 0.7569686, accuracy 64.480%:
# Epoch 49, CIFAR-10 Batch 4:  Loss: 0.7089488, accuracy 64.060%:
# Epoch 49, CIFAR-10 Batch 5:  Loss: 0.7796519, accuracy 64.100%:
# Epoch 50, CIFAR-10 Batch 1:  Loss: 0.7949806, accuracy 63.680%:
# Epoch 50, CIFAR-10 Batch 2:  Loss: 0.8063554, accuracy 64.520%:
# Epoch 50, CIFAR-10 Batch 3:  Loss: 0.7470195, accuracy 63.860%:
# Epoch 50, CIFAR-10 Batch 4:  Loss: 0.7171572, accuracy 64.300%:
# Epoch 50, CIFAR-10 Batch 5:  Loss: 0.7643430, accuracy 64.180%:
# Epoch 51, CIFAR-10 Batch 1:  Loss: 0.7671468, accuracy 64.700%:
# Epoch 51, CIFAR-10 Batch 2:  Loss: 0.8240396, accuracy 63.960%:
# Epoch 51, CIFAR-10 Batch 3:  Loss: 0.7603568, accuracy 64.120%:
# Epoch 51, CIFAR-10 Batch 4:  Loss: 0.6871735, accuracy 64.920%:
# Epoch 51, CIFAR-10 Batch 5:  Loss: 0.7489383, accuracy 64.680%:
# Epoch 52, CIFAR-10 Batch 1:  Loss: 0.7527675, accuracy 64.820%:
# Epoch 52, CIFAR-10 Batch 2:  Loss: 0.7979158, accuracy 63.600%:
# Epoch 52, CIFAR-10 Batch 3:  Loss: 0.7468369, accuracy 64.100%:
# Epoch 52, CIFAR-10 Batch 4:  Loss: 0.7146337, accuracy 63.760%:
# Epoch 52, CIFAR-10 Batch 5:  Loss: 0.7349062, accuracy 65.300%:
# Epoch 53, CIFAR-10 Batch 1:  Loss: 0.7424835, accuracy 65.540%:
# Epoch 53, CIFAR-10 Batch 2:  Loss: 0.7985598, accuracy 64.400%:
# Epoch 53, CIFAR-10 Batch 3:  Loss: 0.7412440, accuracy 64.320%:
# Epoch 53, CIFAR-10 Batch 4:  Loss: 0.6558933, accuracy 64.780%:
# Epoch 53, CIFAR-10 Batch 5:  Loss: 0.7207661, accuracy 64.920%:
# Epoch 54, CIFAR-10 Batch 1:  Loss: 0.7091364, accuracy 65.560%:
# Epoch 54, CIFAR-10 Batch 2:  Loss: 0.7681062, accuracy 64.840%:
# Epoch 54, CIFAR-10 Batch 3:  Loss: 0.7057006, accuracy 65.780%:
# Epoch 54, CIFAR-10 Batch 4:  Loss: 0.6908494, accuracy 63.780%:
# Epoch 54, CIFAR-10 Batch 5:  Loss: 0.7263598, accuracy 65.140%:
# Epoch 55, CIFAR-10 Batch 1:  Loss: 0.7555869, accuracy 65.680%:
# Epoch 55, CIFAR-10 Batch 2:  Loss: 0.7656878, accuracy 65.780%:
# Epoch 55, CIFAR-10 Batch 3:  Loss: 0.7155496, accuracy 65.840%:
# Epoch 55, CIFAR-10 Batch 4:  Loss: 0.6589026, accuracy 65.000%:
# Epoch 55, CIFAR-10 Batch 5:  Loss: 0.6994051, accuracy 65.260%:
# Epoch 56, CIFAR-10 Batch 1:  Loss: 0.7062447, accuracy 66.560%:
# Epoch 56, CIFAR-10 Batch 2:  Loss: 0.7656176, accuracy 65.940%:
# Epoch 56, CIFAR-10 Batch 3:  Loss: 0.6947823, accuracy 65.640%:
# Epoch 56, CIFAR-10 Batch 4:  Loss: 0.6580459, accuracy 65.220%:
# Epoch 56, CIFAR-10 Batch 5:  Loss: 0.6941172, accuracy 65.960%:
# Epoch 57, CIFAR-10 Batch 1:  Loss: 0.6925929, accuracy 66.440%:
# Epoch 57, CIFAR-10 Batch 2:  Loss: 0.7410373, accuracy 65.480%:
# Epoch 57, CIFAR-10 Batch 3:  Loss: 0.7124593, accuracy 65.840%:
# Epoch 57, CIFAR-10 Batch 4:  Loss: 0.6684002, accuracy 65.480%:
# Epoch 57, CIFAR-10 Batch 5:  Loss: 0.6695139, accuracy 66.400%:
# Epoch 58, CIFAR-10 Batch 1:  Loss: 0.6994539, accuracy 66.700%:
# Epoch 58, CIFAR-10 Batch 2:  Loss: 0.7077568, accuracy 66.420%:
# Epoch 58, CIFAR-10 Batch 3:  Loss: 0.6503971, accuracy 66.780%:
# Epoch 58, CIFAR-10 Batch 4:  Loss: 0.6020379, accuracy 66.420%:
# Epoch 58, CIFAR-10 Batch 5:  Loss: 0.6810803, accuracy 66.600%:
# Epoch 59, CIFAR-10 Batch 1:  Loss: 0.6672086, accuracy 66.820%:
# Epoch 59, CIFAR-10 Batch 2:  Loss: 0.7314274, accuracy 66.340%:
# Epoch 59, CIFAR-10 Batch 3:  Loss: 0.6465119, accuracy 67.380%:
# Epoch 59, CIFAR-10 Batch 4:  Loss: 0.6220119, accuracy 65.920%:
# Epoch 59, CIFAR-10 Batch 5:  Loss: 0.6727104, accuracy 66.720%:
# Epoch 60, CIFAR-10 Batch 1:  Loss: 0.6588768, accuracy 67.180%:
# Epoch 60, CIFAR-10 Batch 2:  Loss: 0.7009684, accuracy 66.360%:
# Epoch 60, CIFAR-10 Batch 3:  Loss: 0.6440752, accuracy 66.980%:
# Epoch 60, CIFAR-10 Batch 4:  Loss: 0.5945265, accuracy 66.340%:
# Epoch 60, CIFAR-10 Batch 5:  Loss: 0.6718878, accuracy 66.700%:
# Epoch 61, CIFAR-10 Batch 1:  Loss: 0.6450326, accuracy 66.740%:
# Epoch 61, CIFAR-10 Batch 2:  Loss: 0.7056934, accuracy 67.060%:
# Epoch 61, CIFAR-10 Batch 3:  Loss: 0.6455357, accuracy 66.460%:
# Epoch 61, CIFAR-10 Batch 4:  Loss: 0.5708891, accuracy 66.040%:
# Epoch 61, CIFAR-10 Batch 5:  Loss: 0.6568721, accuracy 66.720%:
# Epoch 62, CIFAR-10 Batch 1:  Loss: 0.6371075, accuracy 67.340%:
# Epoch 62, CIFAR-10 Batch 2:  Loss: 0.6711615, accuracy 66.240%:
# Epoch 62, CIFAR-10 Batch 3:  Loss: 0.6050828, accuracy 67.760%:
# Epoch 62, CIFAR-10 Batch 4:  Loss: 0.5802112, accuracy 66.560%:
# Epoch 62, CIFAR-10 Batch 5:  Loss: 0.6323105, accuracy 67.380%:
# Epoch 63, CIFAR-10 Batch 1:  Loss: 0.6400442, accuracy 67.340%:
# Epoch 63, CIFAR-10 Batch 2:  Loss: 0.6492428, accuracy 67.320%:
# Epoch 63, CIFAR-10 Batch 3:  Loss: 0
# Epoch 82, CIFAR-10 Batch 2:  Loss: 0.5522574, accuracy 68.380%:
# Epoch 82, CIFAR-10 Batch 3:  Loss: 0.5486643, accuracy 68.340%:
# Epoch 82, CIFAR-10 Batch 4:  Loss: 0.4995891, accuracy 67.880%:
# Epoch 82, CIFAR-10 Batch 5:  Loss: 0.5510461, accuracy 67.960%:
# Epoch 83, CIFAR-10 Batch 1:  Loss: 0.5367575, accuracy 68.800%:
# Epoch 83, CIFAR-10 Batch 2:  Loss: 0.5594155, accuracy 68.440%:
# Epoch 83, CIFAR-10 Batch 3:  Loss: 0.5452716, accuracy 68.460%:
# Epoch 83, CIFAR-10 Batch 4:  Loss: 0.4615664, accuracy 67.480%:
# Epoch 83, CIFAR-10 Batch 5:  Loss: 0.5415579, accuracy 68.460%:
# Epoch 84, CIFAR-10 Batch 1:  Loss: 0.5288019, accuracy 68.800%:
# Epoch 84, CIFAR-10 Batch 2:  Loss: 0.5569698, accuracy 68.200%:
# Epoch 84, CIFAR-10 Batch 3:  Loss: 0.5496342, accuracy 68.640%:
# Epoch 84, CIFAR-10 Batch 4:  Loss: 0.4852760, accuracy 68.940%:
# Epoch 84, CIFAR-10 Batch 5:  Loss: 0.5173985, accuracy 68.700%:
# Epoch 85, CIFAR-10 Batch 1:  Loss: 0.5279935, accuracy 68.680%:
# Epoch 85, CIFAR-10 Batch 2:  Loss: 0.5334820, accuracy 68.200%:
# Epoch 85, CIFAR-10 Batch 3:  Loss: 0.5297487, accuracy 68.640%:
# Epoch 85, CIFAR-10 Batch 4:  Loss: 0.4600460, accuracy 68.480%:
# Epoch 85, CIFAR-10 Batch 5:  Loss: 0.5059516, accuracy 68.320%:
# Epoch 86, CIFAR-10 Batch 1:  Loss: 0.5546036, accuracy 69.220%:
# Epoch 86, CIFAR-10 Batch 2:  Loss: 0.5465345, accuracy 68.420%:
# Epoch 86, CIFAR-10 Batch 3:  Loss: 0.5291050, accuracy 69.440%:
# Epoch 86, CIFAR-10 Batch 4:  Loss: 0.4680152, accuracy 67.840%:
# Epoch 86, CIFAR-10 Batch 5:  Loss: 0.4939226, accuracy 68.480%:
# Epoch 87, CIFAR-10 Batch 1:  Loss: 0.5099196, accuracy 69.140%:
# Epoch 87, CIFAR-10 Batch 2:  Loss: 0.5361980, accuracy 69.040%:
# Epoch 87, CIFAR-10 Batch 3:  Loss: 0.5296828, accuracy 68.760%:
# Epoch 87, CIFAR-10 Batch 4:  Loss: 0.4618419, accuracy 68.660%:
# Epoch 87, CIFAR-10 Batch 5:  Loss: 0.5006502, accuracy 68.780%:
# Epoch 88, CIFAR-10 Batch 1:  Loss: 0.5178540, accuracy 69.500%:
# Epoch 88, CIFAR-10 Batch 2:  Loss: 0.5434984, accuracy 68.840%:
# Epoch 88, CIFAR-10 Batch 3:  Loss: 0.5206819, accuracy 69.160%:
# Epoch 88, CIFAR-10 Batch 4:  Loss: 0.4454574, accuracy 69.040%:
# Epoch 88, CIFAR-10 Batch 5:  Loss: 0.5183970, accuracy 68.060%:
# Epoch 89, CIFAR-10 Batch 1:  Loss: 0.5164011, accuracy 69.200%:
# Epoch 89, CIFAR-10 Batch 2:  Loss: 0.5242069, accuracy 69.180%:
# Epoch 89, CIFAR-10 Batch 3:  Loss: 0.5138785, accuracy 69.600%:
# Epoch 89, CIFAR-10 Batch 4:  Loss: 0.4263116, accuracy 69.180%:
# Epoch 89, CIFAR-10 Batch 5:  Loss: 0.4891968, accuracy 68.840%:
# Epoch 90, CIFAR-10 Batch 1:  Loss: 0.4997365, accuracy 69.140%:
# Epoch 90, CIFAR-10 Batch 2:  Loss: 0.5407324, accuracy 67.860%:
# Epoch 90, CIFAR-10 Batch 3:  Loss: 0.5085047, accuracy 69.000%:
# Epoch 90, CIFAR-10 Batch 4:  Loss: 0.4520509, accuracy 68.480%:
# Epoch 90, CIFAR-10 Batch 5:  Loss: 0.4839740, accuracy 68.700%:
# Epoch 91, CIFAR-10 Batch 1:  Loss: 0.5325531, accuracy 68.840%:
# Epoch 91, CIFAR-10 Batch 2:  Loss: 0.5323536, accuracy 68.300%:
# Epoch 91, CIFAR-10 Batch 3:  Loss: 0.5353469, accuracy 68.540%:
# Epoch 91, CIFAR-10 Batch 4:  Loss: 0.4580350, accuracy 67.940%:
# Epoch 91, CIFAR-10 Batch 5:  Loss: 0.4874568, accuracy 69.420%:
# Epoch 92, CIFAR-10 Batch 1:  Loss: 0.5027186, accuracy 70.060%:
# Epoch 92, CIFAR-10 Batch 2:  Loss: 0.5480618, accuracy 68.960%:
# Epoch 92, CIFAR-10 Batch 3:  Loss: 0.5558499, accuracy 67.280%:
# Epoch 92, CIFAR-10 Batch 4:  Loss: 0.4567774, accuracy 68.580%:
# Epoch 92, CIFAR-10 Batch 5:  Loss: 0.4980223, accuracy 69.960%:
# Epoch 93, CIFAR-10 Batch 1:  Loss: 0.5134109, accuracy 69.720%:
# Epoch 93, CIFAR-10 Batch 2:  Loss: 0.5073879, accuracy 69.000%:
# Epoch 93, CIFAR-10 Batch 3:  Loss: 0.5223084, accuracy 68.940%:
# Epoch 93, CIFAR-10 Batch 4:  Loss: 0.4301491, accuracy 68.900%:
# Epoch 93, CIFAR-10 Batch 5:  Loss: 0.4823072, accuracy 68.340%:
# Epoch 94, CIFAR-10 Batch 1:  Loss: 0.5042059, accuracy 69.420%:
# Epoch 94, CIFAR-10 Batch 2:  Loss: 0.5049875, accuracy 69.480%:
# Epoch 94, CIFAR-10 Batch 3:  Loss: 0.5149215, accuracy 69.220%:
# Epoch 94, CIFAR-10 Batch 4:  Loss: 0.4179498, accuracy 68.820%:
# Epoch 94, CIFAR-10 Batch 5:  Loss: 0.4705339, accuracy 69.940%:
# Epoch 95, CIFAR-10 Batch 1:  Loss: 0.5316625, accuracy 68.660%:
# Epoch 95, CIFAR-10 Batch 2:  Loss: 0.5376795, accuracy 69.100%:
# Epoch 95, CIFAR-10 Batch 3:  Loss: 0.5572306, accuracy 68.460%:
# Epoch 95, CIFAR-10 Batch 4:  Loss: 0.4612777, accuracy 69.060%:
# Epoch 95, CIFAR-10 Batch 5:  Loss: 0.4622691, accuracy 69.140%:
# Epoch 96, CIFAR-10 Batch 1:  Loss: 0.5101274, accuracy 69.700%:
# Epoch 96, CIFAR-10 Batch 2:  Loss: 0.5219730, accuracy 69.760%:
# Epoch 96, CIFAR-10 Batch 3:  Loss: 0.5654467, accuracy 67.140%:
# Epoch 96, CIFAR-10 Batch 4:  Loss: 0.4552857, accuracy 67.840%:
# Epoch 96, CIFAR-10 Batch 5:  Loss: 0.4460441, accuracy 69.480%:
# Epoch 97, CIFAR-10 Batch 1:  Loss: 0.4886674, accuracy 69.800%:
# Epoch 97, CIFAR-10 Batch 2:  Loss: 0.4965873, accuracy 69.040%:
# Epoch 97, CIFAR-10 Batch 3:  Loss: 0.5024938, accuracy 68.980%:
# Epoch 97, CIFAR-10 Batch 4:  Loss: 0.4345322, accuracy 68.880%:
# Epoch 97, CIFAR-10 Batch 5:  Loss: 0.4553225, accuracy 69.700%:
# Epoch 98, CIFAR-10 Batch 1:  Loss: 0.4899343, accuracy 69.620%:
# Epoch 98, CIFAR-10 Batch 2:  Loss: 0.4951032, accuracy 68.900%:
# Epoch 98, CIFAR-10 Batch 3:  Loss: 0.5090232, accuracy 69.480%:
# Epoch 98, CIFAR-10 Batch 4:  Loss: 0.4034726, accuracy 69.540%:
# Epoch 98, CIFAR-10 Batch 5:  Loss: 0.4450095, accuracy 69.140%:
# Epoch 99, CIFAR-10 Batch 1:  Loss: 0.5214897, accuracy 69.180%:
# Epoch 99, CIFAR-10 Batch 2:  Loss: 0.5019392, accuracy 68.940%:
# Epoch 99, CIFAR-10 Batch 3:  Loss: 0.5076041, accuracy 68.820%:
# Epoch 99, CIFAR-10 Batch 4:  Loss: 0.4051875, accuracy 69.140%:
# Epoch 99, CIFAR-10 Batch 5:  Loss: 0.4534776, accuracy 68.920%:
# Epoch 100, CIFAR-10 Batch 1:  Loss: 0.4787582, accuracy 70.000%:
# Epoch 100, CIFAR-10 Batch 2:  Loss: 0.5358826, accuracy 68.660%:
# Epoch 100, CIFAR-10 Batch 3:  Loss: 0.5087895, accuracy 68.640%:
# Epoch 100, CIFAR-10 Batch 4:  Loss: 0.4043529, accuracy 68.340%:
# Epoch 100, CIFAR-10 Batch 5:  Loss: 0.4906517, accuracy 68.380%:

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6838982075452804

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
